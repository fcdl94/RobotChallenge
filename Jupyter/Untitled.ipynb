# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from PIL import ImageMath
import sys
sys.path.append('..')

img = Image.open('/home/fcdl/Develop/Data/NYU/train/dining_room/00001406.png') # .convert("RGB")
print(img)

if img.mode != 'RGB':
    if img.mode == 'I':
        from PIL import ImageMath
        img = ImageMath.eval('im/256', {'im': img})
    img = img.convert('L')
    
    #img = img.convert('RGB')

    np_frame = np.array(img)
print(np_frame.shape)
imgplot = plt.imshow(np_frame)
imgplot.axes.get_xaxis().set_visible(False)
imgplot.axes.get_yaxis().set_visible(False)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=I size=640x480 at 0x7F3AC161C2B0>
# (480, 640)

# %%
def pil_loader(path):
    # open path as file to avoid ResourceWarning (https://github.com/python-pillow/Pillow/issues/835)
    with open(path, 'rb') as f:
        img = Image.open(f)
        
        if img.mode == 'I':
            img = ImageMath.eval('im/256', {'im': img})
            
        return img.convert('RGB')

# %%
img = pil_loader('/home/fcdl/Develop/Data/NYU/val/kitchen/00000201.png')

np_frame = np.array(img)
print(np_frame.shape)
imgplot = plt.imshow(np_frame)
# Out:
# (480, 640, 3)

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

im_frame = pil_loader('/home/fcdl/Develop/Data/linemod/linemod/val/ape/depth1129.png')
print(im_frame)
np_frame = np.array(im_frame)
print(np_frame.shape)
imgplot = plt.imshow(np_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7FFD4C735F28>
# (64, 64, 3)

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

im_frame = Image.open('/home/fcdl/Develop/Data/ROD/original/coffee_mug/coffee_mug_1/coffee_mug_1_1_166_depthcrop.png')#.convert("L")
print(im_frame)
np_frame = np.array(im_frame)
print(np_frame.shape)
imgplot = plt.imshow(np_frame)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=I size=103x106 at 0x7F3AC161BC88>
# (106, 103)
