# %%
from PoseEstimation.LinemodDataSet import LinemodDataset
import matplotlib.pyplot as plt

# %%
linemod = LinemodDataset("/home/fcdl/Develop/Data/linemod/")

# %%
plt.ion()
plt.figure()
plt.imshow(linemod[0][0])
print(linemod[0][1])
plt.show()
# Out:
# [0, -0.09630630165338516, 0.9940440058708191, -0.05100790038704872, -0.5733209848403931, -0.013508100062608719, 0.8192200064659119, 0.8136510252952576, 0.1081399992108345, 0.5712069869041443]
